# %% [markdown]
# # CSL558: Machine Learning
#
# **Instructor** : [Dr. Chandra Prakash]
#
# * For more information visit the [class website](https://cprakash86.wordpress.com/ml/).

# %% [markdown]
# # Assignment 4:  Exploratory Data Analysis [EDA] on MNIT Gait DATASET
#
# **Due Date: 26-Aug-2020**
#
#
# **Student Name: Jasmine Ekka**

# %% [markdown]
# # Assignment Instructions
#
#
# You must save your as **Assignment_NO_Yourname**
#
# -----------------------------------------------------------------------------------------------------------------
# ### Agenda for the Assignment 4
# 1. Understand the need of Exploratory Data Analysis on a datset
#
#
# -----------------------------------------------------------------------------------------------------------------
#
# Your source file will most likely end in **.pynb** if you are using a Jupyter notebook; however, it might also end in **.py** if you are using a Python script.
#
# You have to add your name and roll no in the Google Colab Instructions section below and print it.

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
try:
    from google.colab import drive
    # %tensorflow_version 2.x
    COLAB = True
    print("Assignment 4")
    print("Note: using Google CoLab")
except:
    print("Assignment 4")
    print("Note: not using Google CoLab")
    COLAB = False
    
# Print your name and Roll No. 
print("Name: Jasmine Ekka\nRoll No.: 192211006")
# Print the curent time 
import datetime;
print(datetime.datetime.today());
# Out:
# Assignment 4
# Note: using Google CoLab
# Name: Jasmine Ekka
# Roll No.: 192211006
# 2020-08-27 18:30:05.073725

# %% [markdown]
# Some terms w.r.t data :
#
# ![title](https://github.com/prakash27/CSL522_ML/blob/master/assignments/terms.PNG?raw=1)

# %% [markdown]
# [1]: https://www.tutorialspoint.com/python_web_scraping/legality_of_python_web_scraping.htm
# [2]: https://towardsdatascience.com/web-scraping-is-now-legal-6bf0e5730a78

# %% [markdown]
# ### Task 1:   Data reading and package setup
# 1. Read Analysis_MNIT_database.xlsx.  For the task [1-8] you need to consider first Sheet fo xls: data
#
# Based on this dataset you need to identify if the data belongs to male of female cateogry.
# Thus your output is finding the Gender. Rest column you may consider as input
#
#
#     a) Identify the Features/variables in the Dataset

# %%
###Your code here
import numpy as np 
import pandas as pd 
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %%
import seaborn as sns

# %%
# !pip install xlrd

# %%
import matplotlib.pyplot as plt
import numpy as np
# if using a Jupyter notebook, include:
# %matplotlib inline

# %%
df1=pd.read_excel(r'Analysis_MNIT_database.xlsx',sheet_name=["data"])

# %%
df1
# Out:
# {'data':      S.No  Subject # Gender  ...     Cadence  Stride_len  Step_Length
#  0      1.0       S21      M  ...  119.460451    1.211936     0.605968
#  1      2.0       S22      M  ...  152.714500    1.179800     0.589900
#  2      3.0       S23      F  ...  152.810000    1.102700     0.551300
#  3      4.0       S24      F  ...  119.694881    1.337395     0.668697
#  4      5.0       S25      M  ...  112.888200    0.964900     0.482400
#  ..     ...       ...    ...  ...         ...         ...          ...
#  115    NaN       NaN    NaN  ...         NaN         NaN          NaN
#  116    NaN       NaN    NaN  ...         NaN         NaN          NaN
#  117    NaN       NaN    NaN  ...  136.087475    1.195868     0.597934
#  118    NaN       NaN    NaN  ...   52.574876    0.838386     0.419193
#  119    NaN       NaN    NaN  ...  208.625337    1.712000     0.856000
#
#  [120 rows x 21 columns]}

# %%
df2=pd.read_excel(r'Analysis_MNIT_database.xlsx',sheet_name=["Knee_angle"])
df2
# Out:
# {'Knee_angle':     Unnamed: 0  Unnamed: 1  Unnamed: 2  ...  Unnamed: 66  Unnamed: 67  Unnamed: 68
#  0          S21   -0.138624   -0.105468  ...          NaN          NaN          NaN
#  1          S22    2.920620    2.814374  ...          NaN          NaN          NaN
#  2          S23    7.497443    8.860625  ...          NaN          NaN          NaN
#  3          S24    6.076717    6.130036  ...          NaN          NaN          NaN
#  4          S25    1.757879    1.685965  ...          NaN          NaN          NaN
#  ..         ...         ...         ...  ...          ...          ...          ...
#  110       S131    1.563677    2.100017  ...     0.287376     0.247549          NaN
#  111       S132   -6.818130   -5.689363  ...          NaN          NaN          NaN
#  112       S133   -0.880686   -0.984921  ...          NaN          NaN          NaN
#  113       S134         NaN         NaN  ...          NaN          NaN          NaN
# ...

# %%
train_df = pd.read_csv(r'Analysis_MNIT_database.csv')
train_df
# Out:
#      S.No  Subject # Gender  ...     Cadence  Stride_len  Step_Length
# 0      1.0       S21      M  ...  119.460451    1.211936     0.605968
# 1      2.0       S22      M  ...  152.714500    1.179800     0.589900
# 2      3.0       S23      F  ...  152.810000    1.102700     0.551300
# 3      4.0       S24      F  ...  119.694881    1.337395     0.668697
# 4      5.0       S25      M  ...  112.888200    0.964900     0.482400
# ..     ...       ...    ...  ...         ...         ...          ...
# 115    NaN       NaN    NaN  ...         NaN         NaN          NaN
# 116    NaN       NaN    NaN  ...         NaN         NaN          NaN
# 117    NaN       NaN    NaN  ...  136.087475    1.195868     0.597934
# 118    NaN       NaN    NaN  ...   52.574876    0.838386     0.419193
# 119    NaN       NaN    NaN  ...  208.625337    1.712000     0.856000
#
# [120 rows x 21 columns]

# %%
test_df = pd.read_csv(r'/content/sample_data/Analysis_MNIT_database.csv')
test_df
# Out:
#      S.No  Subject # Gender  ...     Cadence  Stride_len  Step_Length
# 0      1.0       S21      M  ...  119.460451    1.211936     0.605968
# 1      2.0       S22      M  ...  152.714500    1.179800     0.589900
# 2      3.0       S23      F  ...  152.810000    1.102700     0.551300
# 3      4.0       S24      F  ...  119.694881    1.337395     0.668697
# 4      5.0       S25      M  ...  112.888200    0.964900     0.482400
# ..     ...       ...    ...  ...         ...         ...          ...
# 115    NaN       NaN    NaN  ...         NaN         NaN          NaN
# 116    NaN       NaN    NaN  ...         NaN         NaN          NaN
# 117    NaN       NaN    NaN  ...  136.087475    1.195868     0.597934
# 118    NaN       NaN    NaN  ...   52.574876    0.838386     0.419193
# 119    NaN       NaN    NaN  ...  208.625337    1.712000     0.856000
#
# [120 rows x 21 columns]

# %%
train_df = train_df.drop(['Mallelous height -L'], axis=1)
#train_df = train_df.drop(['Subject #'], axis=1)
test_df = test_df.drop(['Mallelous height -L'], axis=1)
#train_df = test_df.drop(['Subject #'], axis=1)
#train_df = train_df.drop(['S.No'], axis=1)
#test_df = test_df.drop(['S.No'], axis=1)

train_df
# Out:
#      S.No  Gender  Age (Year)  ...     Cadence  Stride_len  Step_Length
# 0      1.0      M        30.0  ...  119.460451    1.211936     0.605968
# 1      2.0      M        27.0  ...  152.714500    1.179800     0.589900
# 2      3.0      F        27.0  ...  152.810000    1.102700     0.551300
# 3      4.0      F        22.0  ...  119.694881    1.337395     0.668697
# 4      5.0      M        20.0  ...  112.888200    0.964900     0.482400
# ..     ...    ...         ...  ...         ...         ...          ...
# 115    NaN    NaN         NaN  ...         NaN         NaN          NaN
# 116    NaN    NaN         NaN  ...         NaN         NaN          NaN
# 117    NaN    NaN         NaN  ...  136.087475    1.195868     0.597934
# 118    NaN    NaN         NaN  ...   52.574876    0.838386     0.419193
# 119    NaN    NaN         NaN  ...  208.625337    1.712000     0.856000
#
# [120 rows x 19 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   S.No                  114 non-null    float64
#  1   Gender                114 non-null    object
#  2   Age (Year)            114 non-null    float64
#  3   Height (m)            111 non-null    float64
#  4   Weight (Kg)           111 non-null    float64
#  5   BMI                   111 non-null    float64
#  6   Leg Length (m)        111 non-null    float64
#  7   Thigh Length (m)      111 non-null    float64
#  8   Calf Length           114 non-null    float64
#  9   Foot Length (cM)      111 non-null    float64
#  10  Shoe No               111 non-null    float64
#  11  Waist width (inches)  111 non-null    float64
#  12  Bi-illiac width (m)   111 non-null    float64
#  13  Stance                113 non-null    float64
# ...

# %%
train_df.describe()
# Out:
#             S.No   Age (Year)  Height (m)  ...     Cadence  Stride_len  Step_Length
# count  114.000000  114.000000  111.000000  ...  113.000000  113.000000   113.000000
# mean    57.500000   28.096491    1.680315  ...  137.748687    1.234893     0.617446
# std     33.052988    8.831730    0.111664  ...   24.329582    0.170187     0.085094
# min      1.000000    4.000000    0.970000  ...   52.574876    0.838386     0.419193
# 25%     29.250000   23.000000    1.640000  ...  124.863834    1.119287     0.559644
# 50%     57.500000   27.000000    1.680000  ...  138.082956    1.205172     0.602586
# 75%     85.750000   31.000000    1.740000  ...  152.549820    1.345380     0.672690
# max    114.000000   57.000000    1.930000  ...  208.625337    1.712000     0.856000
#
# [8 rows x 18 columns]

# %%
women = train_df[train_df['Gender']=='F']
men = train_df[train_df['Gender']=='M']
women_test = test_df[test_df['Gender']=='F']
men_test = test_df[test_df['Gender']=='M']
women
# Out:
#     S.No  Gender  Age (Year)  ...     Cadence  Stride_len  Step_Length
# 2     3.0      F        27.0  ...  152.810000    1.102700     0.551300
# 3     4.0      F        22.0  ...  119.694881    1.337395     0.668697
# 7     8.0      F        26.0  ...  164.715400    0.968700     0.484400
# 8     9.0      F        20.0  ...  158.778405    1.016483     0.508242
# 9    10.0      F        22.0  ...  144.417821    1.118815     0.559407
# 10   11.0      F        20.0  ...  138.094682    1.171344     0.585672
# 15   16.0      F        26.0  ...  144.268948    1.124138     0.562069
# 16   17.0      F        26.0  ...  150.150900    1.175172     0.587586
# 18   19.0      F        21.0  ...  139.128356    1.129452     0.564726
# 27   28.0      F        25.0  ...  145.025329    1.293597     0.646798
# 29   30.0      F        22.0  ...  134.175084    1.388721     0.694360
# 31   32.0      F        25.0  ...  113.866427    1.320000     0.660000
# ...

# %%
men
# Out:
#      S.No  Gender  Age (Year)  ...     Cadence  Stride_len  Step_Length
# 0      1.0      M        30.0  ...  119.460451    1.211936     0.605968
# 1      2.0      M        27.0  ...  152.714500    1.179800     0.589900
# 4      5.0      M        20.0  ...  112.888200    0.964900     0.482400
# 5      6.0      M        20.0  ...  136.271574    1.404057     0.702029
# 6      7.0      M        28.0  ...  132.387784    1.050904     0.525452
# ..     ...    ...         ...  ...         ...         ...          ...
# 109  110.0      M        25.0  ...  138.123569    1.119287     0.559644
# 110  111.0      M        28.0  ...  144.827586    1.158621     0.579310
# 111  112.0      M        55.0  ...  152.549820    1.014113     0.507056
# 112  113.0      M        42.0  ...  121.590259    1.468966     0.734483
# 113  114.0      M        53.0  ...         NaN         NaN          NaN
#
# [86 rows x 19 columns]

# %% [markdown]
# ### Task 2: Missing Values
# Data preparation may also require us to estimate any missing values within a feature. Model algorithms may work best when there are no missing values.

# %%
###Your code here 
#for women


total = women.isnull().sum().sort_values(ascending=False)
percent_1 = women.isnull().sum()/women.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data
# Out:
#                       Total    %
# Step_Length               1  3.6
# Shoe No                   1  3.6
# Height (m)                1  3.6
# Weight (Kg)               1  3.6
# BMI                       1  3.6
# Leg Length (m)            1  3.6
# Thigh Length (m)          1  3.6
# Stride_len                1  3.6
# Foot Length (cM)          1  3.6
# Waist width (inches)      1  3.6
# Bi-illiac width (m)       1  3.6
# Stance                    1  3.6
# Swing                     1  3.6
# Velocity                  1  3.6
# Cadence                   1  3.6
# Calf Length               0  0.0
# Age (Year)                0  0.0
# Gender                    0  0.0
# S.No                      0  0.0

# %%
###Your code here 
#for men


total = men.isnull().sum().sort_values(ascending=False)
percent_1 = men.isnull().sum()/men.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data
# Out:
#                       Total    %
# Step_Length               3  3.5
# Cadence                   3  3.5
# Velocity                  3  3.5
# Swing                     3  3.5
# Stance                    3  3.5
# Stride_len                3  3.5
# Thigh Length (m)          2  2.3
# Height (m)                2  2.3
# Weight (Kg)               2  2.3
# BMI                       2  2.3
# Leg Length (m)            2  2.3
# Foot Length (cM)          2  2.3
# Shoe No                   2  2.3
# Waist width (inches)      2  2.3
# Bi-illiac width (m)       2  2.3
# Calf Length               0  0.0
# Age (Year)                0  0.0
# Gender                    0  0.0
# S.No                      0  0.0

# %% [markdown]
# ### Task 3 :  EDA : Exploratory Data Analysis similar to the titanic dataset
#
# - **Correlating:** One can approach the problem based on available features within the training dataset. Which features within the dataset contribute significantly to our solution goal? Statistically speaking is there a correlation among a feature and solution goal? As the feature values change does the solution state change as well, and visa-versa? This can be tested both for numerical and categorical features in the given dataset. We may also want to determine correlation among features other than gender for subsequent goals and workflow stages. Correlating certain features may help in creating, completing, or correcting features.
#
# - **Other EDA Techniques**

# %%
###Your code here
# for women
axes = sns.factorplot('Age (Year)','Stance', 
                      data=women, aspect = 2.5, )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
###Your code here
# for men
axes = sns.factorplot('Age (Year)','Stance', 
                      data=men, aspect = 2.5, )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#for women

axes = sns.factorplot('Leg Length (m)','Velocity', 
                      data=women, aspect = 2.5, )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#for men

axes = sns.factorplot('Leg Length (m)','Velocity', 
                      data=men, aspect = 2.5, )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### Task 4:  Data preprocessing and Feature Engg
# - **Correcting:**
#     We may also analyze the given training dataset for errors or possibly innacurate values within features and try to corrent these values or exclude the samples containing the errors. One way to do this is to detect any outliers among our samples or features. We may also completely discard a feature if it is not contribting to the analysis or may significantly skew the results.

# %%
women['Age (Year)']
# Out:
# 2     27.0
# 3     22.0
# 7     26.0
# 8     20.0
# 9     22.0
# 10    20.0
# 15    26.0
# 16    26.0
# 18    21.0
# 27    25.0
# 29    22.0
# 31    25.0
# 35    24.0
# 36    27.0
# 37    27.0
# 39    17.0
# 42    19.0
# 44    15.0
# 46    15.0
# 47    30.0
# 50    21.0
# 53    21.0
# 54    28.0
# 64     4.0
# 67    28.0
# 73    34.0
# 82    36.0
# 86    28.0
# Name: Age (Year), dtype: float64

# %%
men['Age (Year)']
# Out:
# 0      30.0
# 1      27.0
# 4      20.0
# 5      20.0
# 6      28.0
#        ...
# 109    25.0
# 110    28.0
# 111    55.0
# 112    42.0
# 113    53.0
# Name: Age (Year), Length: 86, dtype: float64

# %% [markdown]
# ### Task 5:  Converting Features
#     For modeling stage, one needs to prepare the data. Depending on the choice of model algorithm one may require all features to be converted to numerical equivalent values. So for instance converting text categorical values to numeric values.

# %%
###Your code here
#for women

data_women = [women, women_test]

for dataset_w in data_women:
    dataset_w['Age (Year)'] = dataset_w['Age (Year)'].fillna(0)
    dataset_w['Age (Year)'] = dataset_w['Age (Year)'].astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset_w
# Out:
#     S.No  Subject # Gender  ...     Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...  152.810000    1.102700     0.551300
# 3     4.0       S24      F  ...  119.694881    1.337395     0.668697
# 7     8.0       S28      F  ...  164.715400    0.968700     0.484400
# 8     9.0       S29      F  ...  158.778405    1.016483     0.508242
# 9    10.0       S30      F  ...  144.417821    1.118815     0.559407
# 10   11.0       S31      F  ...  138.094682    1.171344     0.585672
# 15   16.0       S36      F  ...  144.268948    1.124138     0.562069
# 16   17.0       S37      F  ...  150.150900    1.175172     0.587586
# 18   19.0       S39      F  ...  139.128356    1.129452     0.564726
# 27   28.0       S48      F  ...  145.025329    1.293597     0.646798
# 29   30.0       S50      F  ...  134.175084    1.388721     0.694360
# 31   32.0       S52      F  ...  113.866427    1.320000     0.660000
# 35   36.0       S56      F  ...         NaN         NaN          NaN
# ...

# %%
#for men

data_men = [men, men_test]

for dataset_m in data_men:
    dataset_m['Age (Year)'] = dataset_m['Age (Year)'].fillna(0)
    dataset_m['Age (Year)'] = dataset_m['Age (Year)'].astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
dataset_m
# Out:
#      S.No  Subject # Gender  ...     Cadence  Stride_len  Step_Length
# 0      1.0       S21      M  ...  119.460451    1.211936     0.605968
# 1      2.0       S22      M  ...  152.714500    1.179800     0.589900
# 4      5.0       S25      M  ...  112.888200    0.964900     0.482400
# 5      6.0       S26      M  ...  136.271574    1.404057     0.702029
# 6      7.0       S27      M  ...  132.387784    1.050904     0.525452
# ..     ...       ...    ...  ...         ...         ...          ...
# 109  110.0      S130      M  ...  138.123569    1.119287     0.559644
# 110  111.0      S131      M  ...  144.827586    1.158621     0.579310
# 111  112.0      S132      M  ...  152.549820    1.014113     0.507056
# 112  113.0      S133      M  ...  121.590259    1.468966     0.734483
# 113  114.0      S133      M  ...         NaN         NaN          NaN
#
# [86 rows x 20 columns]

# %%
##genders = {"M": 0, "F": 1}
#data = [train_df, test_df]

#for dataset in data:
   # dataset['Gender'] = dataset['Gender'].map(genders)

# %%
#for women

data_w = [women, women_test]

for dataset_w in data_w:
    dataset_w['Weight (Kg)'] = dataset_w['Weight (Kg)'].fillna(0)
    dataset_w['Weight (Kg)'] = dataset_w['Weight (Kg)'].astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
dataset_w
# Out:
#     S.No  Subject # Gender  ...     Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...  152.810000    1.102700     0.551300
# 3     4.0       S24      F  ...  119.694881    1.337395     0.668697
# 7     8.0       S28      F  ...  164.715400    0.968700     0.484400
# 8     9.0       S29      F  ...  158.778405    1.016483     0.508242
# 9    10.0       S30      F  ...  144.417821    1.118815     0.559407
# 10   11.0       S31      F  ...  138.094682    1.171344     0.585672
# 15   16.0       S36      F  ...  144.268948    1.124138     0.562069
# 16   17.0       S37      F  ...  150.150900    1.175172     0.587586
# 18   19.0       S39      F  ...  139.128356    1.129452     0.564726
# 27   28.0       S48      F  ...  145.025329    1.293597     0.646798
# 29   30.0       S50      F  ...  134.175084    1.388721     0.694360
# 31   32.0       S52      F  ...  113.866427    1.320000     0.660000
# 35   36.0       S56      F  ...         NaN         NaN          NaN
# ...

# %%
#for women

data_w = [women, women_test]

for dataset_w in data_w:
    dataset_w['BMI'] = dataset_w['BMI'].fillna(0)
    dataset_w['BMI'] = dataset_w['BMI'].astype(int)

    dataset_w['Shoe No'] = dataset_w['Shoe No'].fillna(0)
    dataset_w['Shoe No'] = dataset_w['Shoe No'].astype(int)

    dataset_w['Stance'] = dataset_w['Stance'].fillna(0)
    dataset_w['Stance'] = dataset_w['Stance'].astype(int)

    dataset_w['Swing'] = dataset_w['Swing'].fillna(0)
    dataset_w['Swing'] = dataset_w['Swing'].astype(int)

    #dataset['Velocity'] = dataset['Velocity'].fillna(0)
    #dataset['Velocity'] = dataset['Velocity'].astype(int)

    dataset_w['Cadence'] = dataset_w['Cadence'].fillna(0)
    dataset_w['Cadence'] = dataset_w['Cadence'].astype(int)

    dataset_w['Stride_len'] = dataset_w['Stride_len'].fillna(0)
    dataset_w['Stride_len'] = dataset_w['Stride_len'].astype(int)

    #dataset['Step_Length'] = dataset['Step_Length'].fillna(0)
    #dataset['Step_Length'] = dataset['Step_Length'].astype(int)

    dataset_w['Waist width (inches)'] = dataset_w['Waist width (inches)'].fillna(0)
    dataset_w['Waist width (inches)'] = dataset_w['Waist width (inches)'].astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dataset_w
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %% [markdown]
# ### Task 6:  Creating Categories

# %%
###Your code here
#for women

data = [women, women_test]
for dataset in data:
    #dataset['Height (m)'] = dataset['Height (m)'].astype(int)
    dataset.loc[ dataset['Height (m)'] <= 1.5, 'Height (m)'] = 0
    dataset.loc[(dataset['Height (m)'] > 1.5) & (dataset['Height (m)'] <= 1.6), 'Height (m)'] = 1
    dataset.loc[(dataset['Height (m)'] > 1.6) & (dataset['Height (m)'] <= 1.7), 'Height (m)'] = 2
    dataset.loc[(dataset['Height (m)'] > 1.7) & (dataset['Height (m)'] <= 1.8), 'Height (m)'] = 3
    dataset.loc[(dataset['Height (m)'] > 1.8) & (dataset['Height (m)'] <= 1.9), 'Height (m)'] = 4
    #dataset.loc[(dataset['Height (m)'] > 33) & (dataset['Height (m)'] <= 40), 'Height (m)'] = 5
    #dataset.loc[(dataset['Height (m)'] > 40) & (dataset['Height (m)'] <= 66), 'Height (m)'] = 6
    #dataset.loc[ dataset['Height (m)'] > 66, 'Height (m)'] = 7
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Height (m)"].mean()
    std = women_test["Height (m)"].std()
    is_null = dataset["Height (m)"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_height = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in height column with random values generated
    height_slice = dataset["Height (m)"].copy()
    height_slice[np.isnan(height_slice)] = rand_height
    dataset["Height (m)"] = height_slice
    dataset["Height (m)"] = women["Height (m)"].astype(int)
women["Height (m)"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Weight (Kg)"].mean()
    std = women_test["Weight (Kg)"].std()
    is_null = dataset["Weight (Kg)"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_weight = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in weight column with random values generated
    weight_slice = dataset["Weight (Kg)"].copy()
    weight_slice[np.isnan(weight_slice)] = rand_weight
    dataset["Weight (Kg)"] = weight_slice
    dataset["Weight (Kg)"] = women["Weight (Kg)"].astype(int)
women["Weight (Kg)"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    #dataset['Height (m)'] = dataset['Height (m)'].astype(int)
    dataset.loc[ dataset['Leg Length (m)'] <= 0.85, 'Leg Length (m)'] = 0
    dataset.loc[(dataset['Leg Length (m)'] > 0.85) & (dataset['Leg Length (m)'] <= 0.90), 'Leg Length (m)'] = 1
    dataset.loc[(dataset['Leg Length (m)'] > 0.90) & (dataset['Leg Length (m)'] <= 0.95), 'Leg Length (m)'] = 2
    dataset.loc[(dataset['Leg Length (m)'] > 0.95) & (dataset['Leg Length (m)'] <= 1.00), 'Leg Length (m)'] = 3
    dataset.loc[(dataset['Leg Length (m)'] > 1.00) & (dataset['Leg Length (m)'] <= 1.50), 'Leg Length (m)'] = 4
    #dataset.loc[(dataset['Height (m)'] > 33) & (dataset['Height (m)'] <= 40), 'Height (m)'] = 5
    #dataset.loc[(dataset['Height (m)'] > 40) & (dataset['Height (m)'] <= 66), 'Height (m)'] = 6
    #dataset.loc[ dataset['Height (m)'] > 66, 'Height (m)'] = 7
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Leg Length (m)"].mean()
    std = women_test["Leg Length (m)"].std()
    is_null = dataset["Leg Length (m)"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_leglen = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in weight column with random values generated
    leglen_slice = dataset["Leg Length (m)"].copy()
    leglen_slice[np.isnan(leglen_slice)] = rand_leglen
    dataset["Leg Length (m)"] = leglen_slice
    dataset["Leg Length (m)"] = women["Leg Length (m)"].astype(int)
women["Leg Length (m)"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    #dataset['Height (m)'] = dataset['Height (m)'].astype(int)
    dataset.loc[ dataset['Thigh Length (m)'] <= 0.45, 'Thigh Length (m)'] = 0
    dataset.loc[(dataset['Thigh Length (m)'] > 0.45) & (dataset['Thigh Length (m)'] <=0.50), 'Thigh Length (m)'] = 1
    dataset.loc[(dataset['Thigh Length (m)'] >0.50) & (dataset['Thigh Length (m)'] <=0.55), 'Thigh Length (m)'] = 2
    dataset.loc[(dataset['Thigh Length (m)'] > 0.55) & (dataset['Thigh Length (m)'] <= 0.60), 'Thigh Length (m)'] = 3
    #dataset.loc[(dataset['Leg Length (m)'] > 1.8) & (dataset['Leg Length (m)'] <= 1.9), 'Leg Length (m)'] = 4
    #dataset.loc[(dataset['Height (m)'] > 33) & (dataset['Height (m)'] <= 40), 'Height (m)'] = 5
    #dataset.loc[(dataset['Height (m)'] > 40) & (dataset['Height (m)'] <= 66), 'Height (m)'] = 6
    #dataset.loc[ dataset['Height (m)'] > 66, 'Height (m)'] = 7
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Thigh Length (m)"].mean()
    std = women_test["Thigh Length (m)"].std()
    is_null = dataset["Thigh Length (m)"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_thighlen = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in weight column with random values generated
    thighlen_slice = dataset["Thigh Length (m)"].copy()
    thighlen_slice[np.isnan(thighlen_slice)] = rand_thighlen
    dataset["Thigh Length (m)"] = thighlen_slice
    dataset["Thigh Length (m)"] = women["Thigh Length (m)"].astype(int)
women["Thigh Length (m)"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    #dataset['Height (m)'] = dataset['Height (m)'].astype(int)
    dataset.loc[ dataset['Calf Length'] <= 0.25, 'Calf Length'] = 0
    dataset.loc[(dataset['Calf Length'] > 0.25) & (dataset['Calf Length'] <=0.30), 'Calf Length'] = 1
    dataset.loc[(dataset['Calf Length'] >0.30) & (dataset['Calf Length'] <=0.35), 'Calf Length'] = 2
    dataset.loc[(dataset['Calf Length'] > 0.35) & (dataset['Calf Length'] <= 0.40), 'Calf Length'] = 3
    dataset.loc[(dataset['Calf Length'] > 0.40) & (dataset['Calf Length'] <= 0.45), 'Calf Length'] = 4
    dataset.loc[(dataset['Calf Length'] > 0.45) & (dataset['Calf Length'] <= 0.50), 'Calf Length'] = 5
    dataset.loc[(dataset['Calf Length'] > 0.50) & (dataset['Calf Length'] <= 0.55), 'Calf Length'] = 6
    #dataset.loc[ dataset['Calf Length'] >0.50, 'Calf Length'] = 6
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Calf Length"].mean()
    std = women_test["Calf Length"].std()
    is_null = dataset["Calf Length"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_calflen = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in calf column with random values generated
    calflen_slice = dataset["Calf Length"].copy()
    calflen_slice[np.isnan(calflen_slice)] = rand_calflen
    dataset["Calf Length"] = calflen_slice
    dataset["Calf Length"] = women["Calf Length"].astype(int)
women["Calf Length"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    #dataset['Height (m)'] = dataset['Height (m)'].astype(int)
    dataset.loc[ dataset['Foot Length (cM)'] <= 0.20, 'Foot Length (cM)'] = 0
    dataset.loc[(dataset['Foot Length (cM)'] > 0.20) & (dataset['Foot Length (cM)'] <=0.22), 'Foot Length (cM)'] = 1
    dataset.loc[(dataset['Foot Length (cM)'] >0.22) & (dataset['Foot Length (cM)'] <=0.24), 'Foot Length (cM)'] = 2
    dataset.loc[(dataset['Foot Length (cM)'] > 0.24) & (dataset['Foot Length (cM)'] <= 0.26), 'Foot Length (cM)'] = 3
    dataset.loc[(dataset['Foot Length (cM)'] > 0.26) & (dataset['Foot Length (cM)'] <= 0.28), 'Foot Length (cM)'] = 4
    dataset.loc[(dataset['Foot Length (cM)'] > 0.28) & (dataset['Foot Length (cM)'] <= 0.30), 'Foot Length (cM)'] = 5
    dataset.loc[(dataset['Foot Length (cM)'] > 0.30) & (dataset['Foot Length (cM)'] <= 0.32), 'Foot Length (cM)'] = 6
    #dataset.loc[ dataset['Calf Length'] >0.50, 'Calf Length'] = 6
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Foot Length (cM)"].mean()
    std = women_test["Foot Length (cM)"].std()
    is_null = dataset["Foot Length (cM)"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_footlen = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in calf column with random values generated
    footlen_slice = dataset["Foot Length (cM)"].copy()
    footlen_slice[np.isnan(footlen_slice)] = rand_footlen
    dataset["Foot Length (cM)"] = footlen_slice
    dataset["Foot Length (cM)"] = women["Foot Length (cM)"].astype(int)
women["Foot Length (cM)"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    #dataset['Bi-illiac width (m)'] = dataset['Bi-illiac width (m)'].astype(int)
    dataset.loc[ dataset['Bi-illiac width (m)'] <= 0.75, 'Bi-illiac width (m)'] = 0
    dataset.loc[(dataset['Bi-illiac width (m)'] > 0.75) & (dataset['Bi-illiac width (m)'] <=0.82), 'Bi-illiac width (m)'] = 1
    dataset.loc[(dataset['Bi-illiac width (m)'] >0.80) & (dataset['Bi-illiac width (m)'] <=0.85), 'Bi-illiac width (m)'] = 2
    dataset.loc[(dataset['Bi-illiac width (m)'] > 0.85) & (dataset['Bi-illiac width (m)'] <= 0.90), 'Bi-illiac width (m)'] = 3
    dataset.loc[(dataset['Bi-illiac width (m)'] > 0.90) & (dataset['Bi-illiac width (m)'] <= 0.95), 'Bi-illiac width (m)'] = 4
    dataset.loc[(dataset['Bi-illiac width (m)'] > 0.95) & (dataset['Bi-illiac width (m)'] <= 1.00), 'Bi-illiac width (m)'] = 5
    dataset.loc[(dataset['Bi-illiac width (m)'] > 1.00) & (dataset['Bi-illiac width (m)'] <= 1.50), 'Bi-illiac width (m)'] = 6
    #dataset.loc[ dataset['Calf Length'] >0.50, 'Calf Length'] = 6
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Bi-illiac width (m)"].mean()
    std = women_test["Bi-illiac width (m)"].std()
    is_null = dataset["Bi-illiac width (m)"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_bilen = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in calf column with random values generated
    bilen_slice = dataset["Bi-illiac width (m)"].copy()
    bilen_slice[np.isnan(bilen_slice)] = rand_bilen
    dataset["Bi-illiac width (m)"] = footlen_slice
    dataset["Bi-illiac width (m)"] = women["Bi-illiac width (m)"].astype(int)
women["Bi-illiac width (m)"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    #dataset['Bi-illiac width (m)'] = dataset['Bi-illiac width (m)'].astype(int)
    dataset.loc[ dataset['Velocity'] <= 1.0, 'Velocity'] = 0
    dataset.loc[(dataset['Velocity'] > 1.0) & (dataset['Velocity'] <=1.1), 'Velocity'] = 1
    dataset.loc[(dataset['Velocity'] >1.1) & (dataset['Velocity'] <=1.2), 'Velocity'] = 2
    dataset.loc[(dataset['Velocity'] > 1.2) & (dataset['Velocity'] <= 1.3), 'Velocity'] = 3
    dataset.loc[(dataset['Velocity'] > 1.3) & (dataset['Velocity'] <= 1.4), 'Velocity'] = 4
    dataset.loc[(dataset['Velocity'] > 1.4) & (dataset['Velocity'] <= 1.5), 'Velocity'] = 5
    dataset.loc[(dataset['Velocity'] > 1.5) & (dataset['Velocity'] <= 1.6), 'Velocity'] = 6
    dataset.loc[(dataset['Velocity'] > 1.6) & (dataset['Velocity'] <= 1.7), 'Velocity'] = 7
    dataset.loc[(dataset['Velocity'] > 1.7) & (dataset['Velocity'] <= 1.8), 'Velocity'] = 8
    #dataset.loc[ dataset['Calf Length'] >0.50, 'Calf Length'] = 6
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Velocity"].mean()
    std = women_test["Velocity"].std()
    is_null = dataset["Velocity"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    velocity_bilen = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in calf column with random values generated
    velocity_slice = dataset["Velocity"].copy()
    velocity_slice[np.isnan(velocity_slice)] = velocity_bilen
    dataset["Velocity"] = footlen_slice
    dataset["Velocity"] = women["Velocity"].astype(int)
women["Velocity"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1     0.551300
# 3     4.0       S24      F  ...      119           1     0.668697
# 7     8.0       S28      F  ...      164           0     0.484400
# 8     9.0       S29      F  ...      158           1     0.508242
# 9    10.0       S30      F  ...      144           1     0.559407
# 10   11.0       S31      F  ...      138           1     0.585672
# 15   16.0       S36      F  ...      144           1     0.562069
# 16   17.0       S37      F  ...      150           1     0.587586
# 18   19.0       S39      F  ...      139           1     0.564726
# 27   28.0       S48      F  ...      145           1     0.646798
# 29   30.0       S50      F  ...      134           1     0.694360
# 31   32.0       S52      F  ...      113           1     0.660000
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    #dataset['Step_Length'] = dataset['Step_Length'].astype(int)
    dataset.loc[ dataset['Step_Length'] <= 0.45, 'Step_Length'] = 0
    dataset.loc[(dataset['Step_Length'] > 0.45) & (dataset['Step_Length'] <=0.50), 'Step_Length'] = 1
    dataset.loc[(dataset['Step_Length'] >0.50) & (dataset['Step_Length'] <=0.60), 'Step_Length'] = 2
    dataset.loc[(dataset['Step_Length'] > 0.60) & (dataset['Step_Length'] <= 0.65), 'Step_Length'] = 3
    dataset.loc[(dataset['Step_Length'] > 0.65) & (dataset['Step_Length'] <= 0.70), 'Step_Length'] = 4
    dataset.loc[(dataset['Step_Length'] > 0.70) & (dataset['Step_Length'] <= 0.75), 'Step_Length'] = 5
    dataset.loc[(dataset['Step_Length'] > 1.75) & (dataset['Step_Length'] <= 0.80), 'Step_Length'] = 6
    dataset.loc[(dataset['Step_Length'] > 0.80) & (dataset['Step_Length'] <= 0.85), 'Step_Length'] = 7
    dataset.loc[(dataset['Step_Length'] > 0.85) & (dataset['Step_Length'] <= 0.90), 'Step_Length'] = 8
    #dataset.loc[ dataset['Calf Length'] >0.50, 'Calf Length'] = 6
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1          2.0
# 3     4.0       S24      F  ...      119           1          4.0
# 7     8.0       S28      F  ...      164           0          1.0
# 8     9.0       S29      F  ...      158           1          2.0
# 9    10.0       S30      F  ...      144           1          2.0
# 10   11.0       S31      F  ...      138           1          2.0
# 15   16.0       S36      F  ...      144           1          2.0
# 16   17.0       S37      F  ...      150           1          2.0
# 18   19.0       S39      F  ...      139           1          2.0
# 27   28.0       S48      F  ...      145           1          3.0
# 29   30.0       S50      F  ...      134           1          4.0
# 31   32.0       S52      F  ...      113           1          4.0
# 35   36.0       S56      F  ...        0           0          NaN
# ...

# %%
data = [women, women_test]

for dataset in data:
    mean = women["Step_Length"].mean()
    std = women_test["Step_Length"].std()
    is_null = dataset["Step_Length"].isnull().sum()
    # compute random numbers between the mean, std and is_null
    rand_step = np.random.randint(mean - std, mean + std, size = is_null)
    # fill NaN values in calf column with random values generated
    step_slice = dataset["Step_Length"].copy()
    step_slice[np.isnan(step_slice)] = rand_step
    dataset["Step_Length"] = footlen_slice
    dataset["Step_Length"] = women["Step_Length"].astype(int)
women["Step_Length"].isnull().sum()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1            2
# 3     4.0       S24      F  ...      119           1            2
# 7     8.0       S28      F  ...      164           0            1
# 8     9.0       S29      F  ...      158           1            2
# 9    10.0       S30      F  ...      144           1            2
# 10   11.0       S31      F  ...      138           1            2
# 15   16.0       S36      F  ...      144           1            1
# 16   17.0       S37      F  ...      150           1            1
# 18   19.0       S39      F  ...      139           1            1
# 27   28.0       S48      F  ...      145           1            2
# 29   30.0       S50      F  ...      134           1            2
# 31   32.0       S52      F  ...      113           1            2
# 35   36.0       S56      F  ...        0           0            2
# ...

# %%
data = [women, women_test]

for dataset in data:
    #dataset['Step_Length'] = dataset['Step_Length'].astype(int)
    dataset.loc[ dataset['Age (Year)'] <= 10, 'Age (Year)'] = 0
    dataset.loc[(dataset['Age (Year)'] > 10) & (dataset['Age (Year)'] <=15), 'Age (Year)'] = 1
    dataset.loc[(dataset['Age (Year)'] >15) & (dataset['Age (Year)'] <=20), 'Age (Year)'] = 2
    dataset.loc[(dataset['Age (Year)'] > 20) & (dataset['Age (Year)'] <= 25), 'Age (Year)'] = 3
    dataset.loc[(dataset['Age (Year)'] > 25) & (dataset['Age (Year)'] <= 30), 'Age (Year)'] = 4
    dataset.loc[(dataset['Age (Year)'] > 30) & (dataset['Age (Year)'] <= 35), 'Age (Year)'] = 5
    dataset.loc[(dataset['Age (Year)'] > 35) & (dataset['Age (Year)'] <= 40), 'Age (Year)'] = 6
    #dataset.loc[(dataset['Age (Year)'] > 0.80) & (dataset['Age (Year)'] <= 0.85), 'Age (Year)'] = 7
    #dataset.loc[(dataset['Age (Year)'] > 0.85) & (dataset['Age (Year)'] <= 0.90), 'Age (Year)'] = 8
    #dataset.loc[ dataset['Calf Length'] >0.50, 'Calf Length'] = 6
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Cadence  Stride_len  Step_Length
# 2     3.0       S23      F  ...      152           1            2
# 3     4.0       S24      F  ...      119           1            2
# 7     8.0       S28      F  ...      164           0            1
# 8     9.0       S29      F  ...      158           1            2
# 9    10.0       S30      F  ...      144           1            2
# 10   11.0       S31      F  ...      138           1            2
# 15   16.0       S36      F  ...      144           1            1
# 16   17.0       S37      F  ...      150           1            1
# 18   19.0       S39      F  ...      139           1            1
# 27   28.0       S48      F  ...      145           1            2
# 29   30.0       S50      F  ...      134           1            2
# 31   32.0       S52      F  ...      113           1            2
# 35   36.0       S56      F  ...        0           0            2
# ...

# %% [markdown]
# ### Task 7: Creating new features
# - **Creating:**
# Can we create new features based on an existing feature or a set of features, such that the new feature follows the correlation, conversion, completeness goals.

# %%
###Your code here

data = [women, women_test]
for dataset in data:
    dataset['Speed']= dataset['Age (Year)']/ dataset['Velocity']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
dataset
# Out:
#     S.No  Subject # Gender  ...  Stride_len  Step_Length     Speed
# 2     3.0       S23      F  ...           1            2  2.000000
# 3     4.0       S24      F  ...           1            2  1.500000
# 7     8.0       S28      F  ...           0            1  4.000000
# 8     9.0       S29      F  ...           1            2  1.000000
# 9    10.0       S30      F  ...           1            2  1.500000
# 10   11.0       S31      F  ...           1            2  1.000000
# 15   16.0       S36      F  ...           1            1  4.000000
# 16   17.0       S37      F  ...           1            1  4.000000
# 18   19.0       S39      F  ...           1            1  3.000000
# 27   28.0       S48      F  ...           1            2  1.500000
# 29   30.0       S50      F  ...           1            2  1.500000
# 31   32.0       S52      F  ...           1            2  1.500000
# 35   36.0       S56      F  ...           0            2  1.500000
# ...

# %% [markdown]
# ### Task 8:
# - **Charting:**
#     How to select the right visualization plots and charts depending on nature of the data and the solution goals.

# %%
###Your code here

plt.plot( 'Age (Year)', 'Velocity', data=dataset, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.xlabel('Age', fontweight='bold')
plt.ylabel('Velocity', fontweight='bold')
plt.legend()

# %%
plt.plot( 'Age (Year)', 'Stride_len', data=dataset, marker='', color='olive', linewidth=2)
plt.plot( 'Age (Year)', 'Step_Length', data=dataset, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.xlabel('Age', fontweight='bold')
plt.legend()

# %%
sns.regplot(x=dataset["Weight (Kg)"], y=dataset["Stance"])

# %%
sns.regplot(x=dataset["Weight (Kg)"], y=dataset["Cadence"])

# %% [markdown]
# ### Task 9:  Plot the knee output for any 1 subejct  from the second sheet

# %%
df = pd.read_csv(r'/content/sample_data/Analysis_MNIT_database2.csv')
df
# Out:
#     S21\t-0.138623706\t-0.105468444\t1.557841671\t4.082138288\t6.882635553\t9.716510194\t12.51319103\t15.09253541\t17.07329042\t18.0446743\t17.83644716\t16.64822554\t14.9047442\t13.04539518\t11.39530959\t10.06284156\t8.890139991\t7.630108391\t6.183714997\t4.672285723\t3.292570439\t2.16666255\t1.323454107\t0.780280681\t0.590926831\t0.844650972\t1.598502735\t2.839321872\t4.54050128\t6.727779185\t9.464407496\t12.82407886\t16.87936677\t21.69202579\t27.24096894\t33.29052076\t39.26639443\t44.39384428\t48.09078807\t50.24687137\t51.12634957\t51.10457546\t50.44803723\t49.25658261\t47.49601278\t45.03347285\t41.6979906\t37.40519945\t32.23628862\t26.44240859\t20.42631944\t14.70690143\t17.82043663\t12.2334241\t5.792605399\t1.088496376\t-1.370223246\t-3.892913135\t-5.918307717\t\t\t\t\t\t\t\t\t
# 0    S22\t2.920619701\t2.814374157\t4.541029013\t7....
# 1    S23\t7.497442724\t8.860624905\t11.24041314\t13...
# 2    S24\t6.07671687\t6.130036309\t7.605894081\t9.6...
# ...

# %% [markdown]
# ### Task 10: Plot the knee ouput of all the subjects
# 1. Data reading and setup

# %% [markdown]
# ## Supplementary questions : Write your observation from the dataset

# %%
###Your Comment
